# %%
import os
import sys
from datetime import timedelta
from typing import Dict, Any, Optional
import json

import numpy as np
import pandas as pd

from common_utils import load_schema, validate_data

sys.path.append(os.path.abspath("N:\\CancerEpidem\\BrBreakthrough\\DeliveryProcess\\Schema_and_Derivation_utils"))
from utilities import connect_DB, createLogger, read_data
from config import Delivery_log_path, live_server, r0_json_path_ae, out_json_path

# %%
def _floor_years_days(days: Optional[int]) -> Optional[int]:
    """
    Convert a day difference into an integer age in years using 365.25-day years.
    Returns None if days is None or NaN.
    """
    if days is None:
        return None
    try:
        if pd.isna(days):
            return None
    except Exception:
        pass
    try:
        return int(np.floor(float(days) / 365.25))
    except Exception:
        return None

def _to_int_or_none(x: Any) -> Optional[int]:
    """Convert SQL numeric (e.g., REAL/FLOAT) to int, preserving None/NaN."""
    if x is None:
        return None
    try:
        if pd.isna(x):
            return None
    except Exception:
        pass
    try:
        return int(x)
    except Exception:
        try:
            return int(float(x))
        except Exception:
            return None

# %%
def _to_datetime_series(s: pd.Series) -> pd.Series:
    """Coerce a pandas Series to datetime with NaT on failure."""
    return pd.to_datetime(s, errors="coerce")

# %%
def _shift_date(dt: Any, random_days: Any) -> Optional[pd.Timestamp]:
    """
    Apply pseudo-anonymization shift by adding participant-specific Random days.
    Returns None if either is missing/invalid.
    """
    if dt is None:
        return None
    try:
        ts = pd.to_datetime(dt, errors="coerce")
    except Exception:
        return None
    if pd.isna(ts):
        return None

    try:
        rd = int(random_days)
    except Exception:
        return None

    return ts + timedelta(days=rd)

# %%
def _shift_date_str(dt: Any, random_days: Any) -> Optional[str]:
    """
    Shift a date and return an ISO date string (YYYY-MM-DD) or None.
    Matches schema expectation for DOB_Shifted and EntryDate_Shifted.
    """
    shifted = _shift_date(dt, random_days)
    if shifted is None or pd.isna(shifted):
        return None
    return shifted.date().isoformat()

# %%
def mailing_database_load(live_server: str, logger) -> Dict[str, Dict[str, Any]]:
    """
    Load ADOB/EventDate/Random from the Mailing database and derive:

      - DOB_Shifted       (shifted date of birth)
      - YOB       (unshifted year of birth)
      - EntryDate_Shifted (shifted date of entry)
      - EntryYear (actual year of entry, unshifted)
      - AgeEntry  (age in whole years at entry)

    Returns:
        dict[tcode] = {
            "ADOB": <unshifted datetime>,
            "DOB_Shifted": <str or None>,
            "YOB": <int or None>,
            "EntryDate_Shifted": <str or None>,
            "EntryYear": <int or None>,
            "AgeEntry": <int or None>,
        }
    """
    logger.info("Loading Mailing data for entry variable derivation...")

    conn = connect_DB("Mailing", live_server, logger)

    # NOTE: This SELECT is the same logical query as in Derivation.ipynb,
    # but moved here to keep all entry-variable logic together.
    sql = """
    SELECT
        S.StudyID,
        S.TCode,
        S.Random,
        G.ADOB,
        E.EventDate,
        CAST(TY.R1Completion AS INT) AS R1Completion,
        CAST(TY.R1Received AS INT) AS R1Received,
        CAST(TY.R1BloodReceived AS INT) AS R1BloodReceived,
        CAST(TY.R2Completion AS INT) AS R2Completion,
        CAST(TY.R2Received AS INT) AS R2Received,
        CAST(TY.R3Completion AS INT) AS R3Completion,
        CAST(TY.R3Received AS INT) AS R3Received,
        CAST(TY.R4Completion AS INT) AS R4Completion,
        CAST(TY.R4Received AS INT) AS R4Received
    FROM [Mailing].[dbo].[Events]   AS E
    JOIN [Mailing].[dbo].[SIDCodes] AS S
        ON S.PersonID = E.Person
    JOIN [Mailing].[dbo].[General]  AS G
        ON G.PersonID = E.Person
    
    LEFT JOIN [Mailing].[dbo].[TrueYear] AS TY
        ON TY.StudyID = S.StudyID
    WHERE
        E.Cancelled = 0
        AND E.Event = 6
    """

    df = read_data(sql, conn, logger)

    if df.empty:
        logger.warning("No Mailing rows returned; derived entry variables will be empty.")
        return {}

    # Normalise column names (in case of case/space differences)
    df = df.rename(columns={c: c.strip() for c in df.columns})

    # Coerce date columns
    if "ADOB" in df.columns:
        df["ADOB"] = _to_datetime_series(df["ADOB"])
    if "EventDate" in df.columns:
        df["EventDate"] = _to_datetime_series(df["EventDate"])

    out: Dict[str, Dict[str, Any]] = {}

    for _, r in df.iterrows():
        tcode = r.get("TCode")
        if not isinstance(tcode, str) or not tcode:
            continue

        rand = r.get("Random")
        adob = r.get("ADOB")
        evdt = r.get("EventDate")
        study_id = r.get("StudyID")

        dob_shift = _shift_date_str(adob, rand)
        ent_shift = _shift_date_str(evdt, rand)

        yob = int(adob.year) if pd.notna(adob) else None
        entry_year = int(evdt.year) if pd.notna(evdt) else None

        if pd.notna(adob) and pd.notna(evdt):
            age_days = (evdt.date() - adob.date()).days
            age_years = _floor_years_days(age_days)
        else:
            age_years = None

        out[tcode] = {
            # everything below is intended for output
            "DOB_Shifted": dob_shift,
            "YOB": yob,
            "EntryDate_Shifted": ent_shift,
            "EntryYear": entry_year,
            "AgeEntry": age_years,
       
            "R1Completion": _to_int_or_none(r.get("R1Completion")),
            "R1Received": _to_int_or_none(r.get("R1Received")),
            "R1BloodReceived": _to_int_or_none(r.get("R1BloodReceived")),
            "R2Completion": _to_int_or_none(r.get("R2Completion")),
            "R2Received": _to_int_or_none(r.get("R2Received")),
            "R3Completion": _to_int_or_none(r.get("R3Completion")),
            "R3Received": _to_int_or_none(r.get("R3Received")),
            "R4Completion": _to_int_or_none(r.get("R4Completion")),
            "R4Received": _to_int_or_none(r.get("R4Received")),
        }

    logger.info(f"Derived entry variables for {len(out)} participants.")
    
    return out

# %%
if __name__ == "__main__":

    logger = createLogger("DeriveEntryVariables", Delivery_log_path)
    mail_by_tcode = mailing_database_load(live_server, logger)

    # convert to list-of-dicts with TCode for easy JSON dumping
    records = []
    for tcode, vals in mail_by_tcode.items():
        rec = {"TCode": tcode}
        rec.update(vals)
        records.append(rec)

    schema = load_schema(r0_json_path_ae, f"AdminEvents_Schema")
    validate_data(records, schema, r0_json_path_ae)

    out_path = os.path.join(out_json_path, 's5_derived', "AdminEvents.json")
    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(records, f, default=str, indent=2)

    logger.info(f"✓ Saved entry variables JSON to {out_path}")
# Out:
# 2026-02-13 11:46:12 - INFO: Loading Mailing data for entry variable derivation...
# 2026-02-13 11:46:43 - INFO: Derived entry variables for 113766 participants.
# Validating 113,766 items...
# 100% - Validation completed in 28.16 seconds
# ✓ All items are valid
# 2026-02-13 11:47:25 - INFO: ✓ Saved entry variables JSON to N:\CancerEpidem\BrBreakthrough\DeliveryProcess\Data_Output_Testing\s5_derived\AdminEvents.json
