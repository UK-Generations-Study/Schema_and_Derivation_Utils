# %%
import pandas as pd
import json

from common_utils import get_config
from pseudo_anon_utils import load_sid_codes

# %%
config = get_config()
server = config["test_server"]
logger = None

# %%
sid_df = load_sid_codes(server=server, logger=logger)

# %%
sid_df = sid_df[["StudyID", "TCode"]].drop_duplicates()
sid_df["StudyID"] = sid_df["StudyID"].astype(int)

# %%
csv_path = r"N:\CancerEpidem\BrBreakthrough\DeliveryProcess\Data_Output_Testing\temp_fam_hist\Q14famhistcancer.csv"

# %%
csv_studyid = "studyid"
fam_hist_cols = ["famca", "famcaN", "fambrca", "fambrcaN", "famovca", "famovcaN", "famcolorec", "famcolorecN", "famprostate", "famprostateN"]

# %%
df_csv = pd.read_csv(csv_path, usecols=[csv_studyid] + fam_hist_cols)

df_csv[csv_studyid] = df_csv[csv_studyid].astype(int)

# %%
df_merged = sid_df.merge(
    df_csv,
    left_on="StudyID",
    right_on=csv_studyid,
    how="left",
    validate="m:1"
)

# %%
missing = df_merged[df_merged["TCode"].isna()][csv_studyid].unique()

if len(missing) > 0:
    print(f"WARNING: {len(missing)} StudyID(s) in the CSV were not found in SIDCodes")

# %%
df_merged = df_merged.drop(columns=["studyid", "StudyID"])

# %%
rename_map = {
    "TCode": "R0_TCode",
    "famca": "R0_FamHistCancer",
    "famcaN": "R0_FamHistCancerNum", 
    "fambrca": "R0_FamHistBC", 
    "fambrcaN": "R0_FamHistBCNum", 
    "famovca": "R0_FamHistOV", 
    "famovcaN": "R0_FamHistOVNum", 
    "famcolorec": "R0_FamHistColo", 
    "famcolorecN": "R0_FamHistColoNum", 
    "famprostate": "R0_FamHistProst", 
    "famprostateN": "R0_FamHistProstNum"}

df_merged = df_merged.rename(columns=rename_map)

# %%
result = df_merged.to_dict(orient="records")

# %%
output_path = r"N:\CancerEpidem\BrBreakthrough\DeliveryProcess\Data_Output_Testing\temp_fam_hist\fam_hist.json"

with open(output_path, "w") as f:
    json.dump(result, f, indent=2)

# %%
result
# Out:
# [{'R0_TCode': 'T261E618',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F619',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H621',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J623',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C624',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F627',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J631',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C632',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D633',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 1.0,
#   'R0_FamHistOVNum': 1.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E634',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F635',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I638',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J639',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 1.0,
#   'R0_FamHistProstNum': 1.0},
#  {'R0_TCode': 'T261C640',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J647',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C648',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F651',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G652',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C656',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E658',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F659',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G660',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H661',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I662',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J663',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C664',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D665',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F667',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G668',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H669',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I670',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J671',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C672',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E674',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F675',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H677',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 1.0,
#   'R0_FamHistOVNum': 1.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C680',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D681',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E682',
#   'R0_FamHistCancer': nan,
#   'R0_FamHistCancerNum': nan,
#   'R0_FamHistBC': nan,
#   'R0_FamHistBCNum': nan,
#   'R0_FamHistOV': nan,
#   'R0_FamHistOVNum': nan,
#   'R0_FamHistColo': nan,
#   'R0_FamHistColoNum': nan,
#   'R0_FamHistProst': nan,
#   'R0_FamHistProstNum': nan},
#  {'R0_TCode': 'T261F683',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G684',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H685',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C688',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H693',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J695',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 2.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C696',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D697',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F699',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G700',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H701',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 1.0,
#   'R0_FamHistProstNum': 1.0},
#  {'R0_TCode': 'T261I702',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J703',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C704',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D705',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E706',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G708',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J711',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D713',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F715',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G716',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H717',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I718',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J719',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C720',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D721',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E722',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G724',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H725',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I726',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C728',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D729',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E730',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G732',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I734',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C736',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G740',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H741',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 3.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I742',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 1.0,
#   'R0_FamHistProstNum': 1.0},
#  {'R0_TCode': 'T261C744',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D745',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E746',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H749',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I750',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C752',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D753',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E754',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F755',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G756',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I758',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C760',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D761',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H765',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I766',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C768',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D769',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G772',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 1.0,
#   'R0_FamHistProstNum': 1.0},
#  {'R0_TCode': 'T261D777',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E778',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F779',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G780',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H781',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I782',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D785',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E786',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G788',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H789',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E794',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F795',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H797',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I798',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J799',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C800',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D801',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 1.0,
#   'R0_FamHistProstNum': 1.0},
#  {'R0_TCode': 'T261F803',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F811',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H813',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G820',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I822',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C824',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D825',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G828',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 1.0,
#   'R0_FamHistOVNum': 1.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J831',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C832',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F835',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 1.0,
#   'R0_FamHistOVNum': 1.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G836',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H837',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I838',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J839',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C840',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E842',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G844',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H845',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J847',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D849',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H853',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J855',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D857',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E858',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G860',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H861',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C864',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D865',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F867',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G868',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H869',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J871',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261C872',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E874',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F875',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G876',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H877',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D881',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H885',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261I886',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J887',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D889',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E890',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F891',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261H893',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 1.0,
#   'R0_FamHistProstNum': 1.0},
#  {'R0_TCode': 'T261J895',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261D897',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261E898',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261F899',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261G900',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T261J903',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 1.0,
#   'R0_FamHistProstNum': 1.0},
#  {'R0_TCode': 'T261C904',
#   'R0_FamHistCancer': nan,
#   'R0_FamHistCancerNum': nan,
#   'R0_FamHistBC': nan,
#   'R0_FamHistBCNum': nan,
# ...
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263G316',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 1.0,
#   'R0_FamHistOVNum': 1.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263H317',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263J319',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263F323',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263G324',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263C328',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263G332',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 2.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263I334',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263D337',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263F339',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263H341',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263I342',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 2.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263C344',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263D345',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 1.0,
#   'R0_FamHistProstNum': 1.0},
#  {'R0_TCode': 'T263E346',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263F347',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263G348',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263H349',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263I350',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263E354',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263F355',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263G356',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263H357',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263I358',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263J359',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263C360',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263D361',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263F363',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263C368',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263D369',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263E370',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263G372',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263I374',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263C376',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263D377',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263E378',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 3.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263H381',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263J383',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263C384',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263D385',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263F387',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263G388',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 1.0,
#   'R0_FamHistProstNum': 1.0},
#  {'R0_TCode': 'T263J391',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263C392',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263D393',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263E394',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 2.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 1.0,
#   'R0_FamHistOVNum': 1.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263G396',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263H397',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 3.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 1.0,
#   'R0_FamHistColoNum': 1.0,
#   'R0_FamHistProst': 1.0,
#   'R0_FamHistProstNum': 1.0},
#  {'R0_TCode': 'T263D401',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263E402',
#   'R0_FamHistCancer': 1.0,
#   'R0_FamHistCancerNum': 1.0,
#   'R0_FamHistBC': 1.0,
#   'R0_FamHistBCNum': 1.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263G404',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263H405',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263I406',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263J407',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  {'R0_TCode': 'T263D409',
#   'R0_FamHistCancer': 0.0,
#   'R0_FamHistCancerNum': 0.0,
#   'R0_FamHistBC': 0.0,
#   'R0_FamHistBCNum': 0.0,
#   'R0_FamHistOV': 0.0,
#   'R0_FamHistOVNum': 0.0,
#   'R0_FamHistColo': 0.0,
#   'R0_FamHistColoNum': 0.0,
#   'R0_FamHistProst': 0.0,
#   'R0_FamHistProstNum': 0.0},
#  ...]
